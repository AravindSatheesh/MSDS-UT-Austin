# %%
# !git clone https://github.com/AravindSatheesh/MSDS-UT-Austin.git

# !curl -s -L https://www.cs.utexas.edu/~bzhou/dl_class/classification_data.zip -o ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/classification_data.zip && unzip -qo ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/classification_data.zip -d ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/
# !curl -s -L https://www.cs.utexas.edu/~bzhou/dl_class/drive_data.zip -o ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/drive_data.zip && unzip -qo ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/drive_data.zip -d ./MSDS-UT-Austin/Deep\ Learning/Assignment/homework3/

# %%
# navigate to your repo
# %cd /content/MSDS-UT-Austin/Deep Learning/Assignment
# %ls

# go to a specific homework
# %cd homework3
# %ls
# Out:
# /content/MSDS-UT-Austin/Deep Learning/Assignment
# homework1/  homework2/  homework3/
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3
# bundle.py                drive_data/     homework/
# classification_data/     drive_data.zip  README.md
# classification_data.zip  grader/         requirements.txt

# %%
#Changed models.py code
#Created train_classification.py

#For training the model
# !python3 train_classification.py --aug --epochs 20 --mixed_precision
# Out:
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/train_classification.py:52: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=args.mixed_precision and device.type=="cuda")
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/train_classification.py:13: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# [001] loss=0.6938 train_acc=0.7849 val_acc=0.8354
#   saved best to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/homework/classifier.th (val_acc=0.8354)
# [002] loss=0.2632 train_acc=0.9153 val_acc=0.8306
# [003] loss=0.1860 train_acc=0.9392 val_acc=0.7997
# [004] loss=0.1492 train_acc=0.9515 val_acc=0.8515
# ...

# %%
#Created train_detection.py

#For training detection
# !python3 train_detection.py --epochs 25 --mixed_precision --lambda_depth 1.0
# Out:
# Loaded 8000 samples from 16 episodes
# Loaded 2000 samples from 4 episodes
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/train_detection.py:132: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=args.mixed_precision and device.type == "cuda")
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/train_detection.py:46: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=scaler is not None):
# [001] loss=0.1879 train_iou=0.3234 val_iou=0.3279 val_depth=0.0217 val_tp_depth=0.0363
#   ↳ saved best model to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/homework/detector.th (mIoU=0.3279)
# [002] loss=0.0870 train_iou=0.4664 val_iou=0.5878 val_depth=0.0166 val_tp_depth=0.0182
# ...

# %%
# !python3 -m grader homework -v
# Out:
# Public grader loaded.
# [INFO     00:00:001] Classifier
# [INFO     00:00:401]   - Predict                                            [ 10 / 10 ]
# [INFO     00:05:246]   - Accuracy                                           [ 25 / 25 ]
# [WARNING  00:05:246] accuracy: 0.906, required > 0.8
# [INFO     00:05:246]   - Accuracy: Extra Credit                             [ 2 / 2 ]
# [INFO     00:05:248]  --------------------------------------------------    [  37 /  35 ]
# [INFO     00:05:249] Detector
# [INFO     00:05:348]   - Predict                                            [ 10 / 10 ]
# [INFO     00:09:936]   - Segmentation Accuracy                              [ 10 / 10 ]
# [WARNING  00:09:936] accuracy: 0.988, required > 0.97
# [INFO     00:09:936]   - Segmentation IoU                                   [ 25 / 25 ]
# [WARNING  00:09:936] iou: 0.757 required > 0.75
# [WARNING  00:09:936]   - Segmentation IoU: Extra Credit                     [ 0 / 2 ]
# ...

# %%
# !python3 bundle.py homework as238863
# Out:
# models.py
# metrics.py
# detector.th
# __init__.py
# datasets
# classifier.th
# datasets/road_dataset.py
# datasets/road_transforms.py
# datasets/classification_dataset.py
# datasets/road_utils.py
# Submission created: /content/MSDS-UT-Austin/Deep Learning/Assignment/homework3/as238863.zip 1.68 MB

# %%
# !python3 -m grader as238863.zip
# Out:
# Public grader loaded.
# [INFO     00:00:020] Classifier
# [INFO     00:05:240]  * Classifier                                          [  37 /  35 ]
# [INFO     00:05:241] Detector
# [INFO     00:09:919]  * Detector                                            [  67 /  65 ]
# [INFO     00:09:919] Total                                                    104 / 100
