# %% [markdown]
# ## General Colab Tips
# - Modify files by opening/editing them in the UI (double-click to open).
# - `Right click > Refresh` in the Colab file explorer to update the directory.
# - All files are lost when the Colab session disconnects, so make sure back up your work.
# - Do **not** use `drive.mount` for your datasets! Reading from GDrive is super slow.
# - Instead, place datasets into the `/content/` folder and modify your data accordingly.
#
# **Make a copy of this notebook and modify this to whatever workflow you prefer!**
#
# If you have some additional colab tips, please share them on the discussion forum.
#
# ## Setup
#
# First, enable a GPU runtime via `Runtime > Change runtime type > T4 GPU`
#
# Next, upload the your project files to the Colab. You can do this by either
# - using Github (**recommended**)
# - uploading files manually using the UI
#
# ## Github Setup
#
# You can use git from within Google Colab!
#
# For this section, we assume you know how to use git and have already pushed the starter code to a private repo.
#
# Before you continue, make sure you download and push the starter code to your repo.
# It's a good idea to structure your repo something like
# ```
# online_deep_learning/
#     homework1/
#     homework2/
#     ...
# ```
#
# We highly recommend using this workflow as you'll be able to easily pull/commit your changes after modifying your model on Colab.
#
# To do this, you'll need a personal access token from [https://github.com/settings/tokens](https://github.com/settings/tokens)
#
# The easiest thing to do is select "classic" token and make sure you have the `repo` scope selected to allow access to your private repos.
# There's also fine-grained tokens where you can select access to specific repos.
#
# Once you have your token, fill in your information and then run the following cell to clone your git repo to the Colab instance.

# %%
# import os


# os.environ['USER'] = 'bradyz'
# os.environ['REPO'] = 'online_deep_learning'
# os.environ['TOKEN'] = 'mYseCretToKEn'

# do everything in colab's "root" directory
# %cd /content
# !git clone https://github.com/AravindSatheesh/MSDS-UT-Austin.git

# make sure your repo shows up
# %ls
# Out:
# /content
# Cloning into 'MSDS-UT-Austin'...
# remote: Enumerating objects: 260, done.
# remote: Counting objects: 100% (158/158), done.
# remote: Compressing objects: 100% (133/133), done.
# remote: Total 260 (delta 39), reused 139 (delta 22), pack-reused 102 (from 1)
# Receiving objects: 100% (260/260), 76.91 MiB | 3.01 MiB/s, done.
# Resolving deltas: 100% (64/64), done.
# MSDS-UT-Austin/  sample_data/

# %% [markdown]
# ## Code Setup
#
# Move into `homework4/` so we can continue setting up the data / code for training.
#
# This will be the main working directory and the training/grading must be run from this directory.

# %%
# navigate to your repo
# %cd /content/MSDS-UT-Austin/Deep Learning/Assignment/
# %ls

# go to a specific homework
# %cd homework4
# %ls
# Out:
# /content/MSDS-UT-Austin/Deep Learning/Assignment
# homework1/  homework2/  homework3/  homework4/
# /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4
# assets/  bundle.py  grader/  homework/  README.md  requirements.txt

# %% [markdown]
# ## Dataset Setup
#
# Now that your code is all ready, the next step is to download the datasets.
#
# Note: it's good practice to add data directories like `*/drive_data` to your `.gitignore` so you don't accidently commit them to your repo.
#
# Since the datasets used in this class are relatively small, we can simply re-download them if the compute instance crashes/restarts.

# %%
# !rm -rf drive_data
# !curl -s -L https://www.cs.utexas.edu/~bzhou/dl_class/drive_data.zip -o ./drive_data.zip && unzip -qo drive_data.zip
# %ls
# Out:
# assets/    drive_data/     grader/    README.md
# bundle.py  drive_data.zip  homework/  requirements.txt

# %% [markdown]
# ## Model Implementation + Training
#
# Now you should be all set up.
# Next, you'll need to implement
# - `homework/train_planner.py`
# - `homework/models.py`
#
# And then you're ready to train

# %%
# refreshes python imports automatically when you edit the source file
# %load_ext autoreload
# %autoreload 2

# make sure you're in the right directory
# %pwd

from homework.train_planner import train


# your training args don't have to look like this
# this is just how it's structured in the solution
for lr in [1e-2, 1e-3, 1e-4]:
    train(
        model_name="linear_planner",
        transform_pipeline="state_only",
        num_workers=4,
        lr=lr,
        batch_size=128,
        num_epoch=40,
    )

# %%
# !python3 -m homework.train_planner --model mlp_planner --epochs 20
# Out:
# Using device: cuda
# Loaded 8000 samples from 16 episodes
# Loaded 2000 samples from 4 episodes
# Epoch 01: train_loss=7.7643, val_loss=0.6373, longitudinal=0.3319, lateral=0.5353
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.8672)
# Epoch 02: train_loss=3.3321, val_loss=0.5922, longitudinal=0.2264, lateral=0.5055
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.7319)
# Epoch 03: train_loss=2.8546, val_loss=0.5217, longitudinal=0.1960, lateral=0.4632
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.6592)
# Epoch 04: train_loss=2.6473, val_loss=0.5368, longitudinal=0.1973, lateral=0.5009
# Epoch 05: train_loss=2.5564, val_loss=0.5160, longitudinal=0.1733, lateral=0.4737
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.6470)
# Epoch 06: train_loss=2.4642, val_loss=0.5462, longitudinal=0.1888, lateral=0.5380
# Epoch 07: train_loss=2.4060, val_loss=0.6665, longitudinal=0.1808, lateral=0.7164
# Epoch 08: train_loss=2.3687, val_loss=0.6638, longitudinal=0.1720, lateral=0.7172
# Epoch 09: train_loss=2.3541, val_loss=0.4769, longitudinal=0.1629, lateral=0.4232
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.5862)
# Epoch 10: train_loss=2.3090, val_loss=0.5743, longitudinal=0.1749, lateral=0.5986
# Epoch 11: train_loss=2.3027, val_loss=0.6191, longitudinal=0.1648, lateral=0.6829
# Epoch 12: train_loss=2.2392, val_loss=0.4642, longitudinal=0.1625, lateral=0.4695
# Epoch 13: train_loss=2.2757, val_loss=0.7737, longitudinal=0.1536, lateral=0.8424
# Epoch 14: train_loss=2.2538, val_loss=0.5188, longitudinal=0.1568, lateral=0.5538
# Epoch 15: train_loss=2.1872, val_loss=0.4815, longitudinal=0.1513, lateral=0.5111
# Epoch 16: train_loss=2.2517, val_loss=0.9762, longitudinal=0.1659, lateral=1.0518
# Epoch 17: train_loss=2.1748, val_loss=0.5758, longitudinal=0.1555, lateral=0.6469
# Epoch 18: train_loss=2.1479, val_loss=0.3889, longitudinal=0.1544, lateral=0.4184
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th (L1=0.5728)
# Epoch 19: train_loss=2.1508, val_loss=0.4866, longitudinal=0.1717, lateral=0.5718
# Epoch 20: train_loss=2.1478, val_loss=0.4476, longitudinal=0.1567, lateral=0.5292
# Best model already saved at /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/mlp_planner.th with L1=0.5728

# %%
# !python3 -m homework.train_planner --model transformer_planner --epochs 30 --lr 5e-4
# !python3 -m homework.train_planner --model cnn_planner --epochs 30 --lr 1e-3 --batch_size 64
# Out:
# Using device: cuda
# Loaded 8000 samples from 16 episodes
# Loaded 2000 samples from 4 episodes
# Epoch 01: train_loss=2.7807, val_loss=1.0052, longitudinal=0.1966, lateral=0.9956
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/transformer_planner.th (L1=1.1922)
# Epoch 02: train_loss=2.0934, val_loss=1.4430, longitudinal=0.1904, lateral=1.3995
# Epoch 03: train_loss=2.0403, val_loss=1.1233, longitudinal=0.1692, lateral=1.1143
# Epoch 04: train_loss=2.0089, val_loss=1.0840, longitudinal=0.1562, lateral=1.0667
# Epoch 05: train_loss=1.9892, val_loss=1.3531, longitudinal=0.1628, lateral=1.2939
# Epoch 06: train_loss=1.9813, val_loss=1.0995, longitudinal=0.1553, lateral=1.0816
# Epoch 07: train_loss=1.9759, val_loss=1.1506, longitudinal=0.1403, lateral=1.1285
# Epoch 08: train_loss=1.9524, val_loss=0.9611, longitudinal=0.1505, lateral=0.9926
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/transformer_planner.th (L1=1.1430)
# Epoch 09: train_loss=1.9537, val_loss=0.9308, longitudinal=0.1425, lateral=0.9404
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/transformer_planner.th (L1=1.0829)
# Epoch 10: train_loss=1.9480, val_loss=0.8076, longitudinal=0.1477, lateral=0.8107
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/transformer_planner.th (L1=0.9583)
# Epoch 11: train_loss=1.9417, val_loss=1.2018, longitudinal=0.1636, lateral=1.1965
# Epoch 12: train_loss=1.9440, val_loss=1.0556, longitudinal=0.1447, lateral=1.0402
# Epoch 13: train_loss=1.9347, val_loss=1.0110, longitudinal=0.1552, lateral=1.0333
# Epoch 14: train_loss=1.9365, val_loss=1.3377, longitudinal=0.1865, lateral=1.3043
# Epoch 15: train_loss=1.9451, val_loss=0.8654, longitudinal=0.1398, lateral=0.9307
# Epoch 16: train_loss=1.9240, val_loss=1.1400, longitudinal=0.1567, lateral=1.1565
# Epoch 17: train_loss=1.9369, val_loss=1.1733, longitudinal=0.1398, lateral=1.2169
# Epoch 18: train_loss=1.9246, val_loss=1.2345, longitudinal=0.1596, lateral=1.2164
# Epoch 19: train_loss=1.9130, val_loss=1.0090, longitudinal=0.1434, lateral=1.0217
# Epoch 20: train_loss=1.9236, val_loss=1.3067, longitudinal=0.1439, lateral=1.3027
# Epoch 21: train_loss=1.9082, val_loss=1.2995, longitudinal=0.1556, lateral=1.2492
# Epoch 22: train_loss=1.9069, val_loss=1.2152, longitudinal=0.1678, lateral=1.2027
# Epoch 23: train_loss=1.9031, val_loss=0.9220, longitudinal=0.1588, lateral=0.9867
# Epoch 24: train_loss=1.8984, val_loss=1.0844, longitudinal=0.1390, lateral=1.1429
# Epoch 25: train_loss=1.8939, val_loss=1.1128, longitudinal=0.1821, lateral=1.0635
# Epoch 26: train_loss=1.8896, val_loss=1.1664, longitudinal=0.1920, lateral=1.2054
# Epoch 27: train_loss=1.9055, val_loss=1.0916, longitudinal=0.1573, lateral=1.1574
# Epoch 28: train_loss=1.8868, val_loss=0.9450, longitudinal=0.1493, lateral=0.9977
# Epoch 29: train_loss=1.8762, val_loss=0.9773, longitudinal=0.1729, lateral=0.9803
# Epoch 30: train_loss=1.8737, val_loss=0.9171, longitudinal=0.1593, lateral=0.9832
# Best model already saved at /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/transformer_planner.th with L1=0.9583
# Using device: cuda
# Loaded 8000 samples from 16 episodes
# Loaded 2000 samples from 4 episodes
# Epoch 01: train_loss=2.7814, val_loss=0.6045, longitudinal=0.3473, lateral=0.5250
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.8723)
# Epoch 02: train_loss=1.3381, val_loss=0.5152, longitudinal=0.3593, lateral=0.4967
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.8560)
# Epoch 03: train_loss=1.1447, val_loss=0.5548, longitudinal=0.3437, lateral=0.5814
# Epoch 04: train_loss=0.9964, val_loss=0.4322, longitudinal=0.3546, lateral=0.4483
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.8028)
# Epoch 05: train_loss=0.8823, val_loss=0.5352, longitudinal=0.3299, lateral=0.6163
# Epoch 06: train_loss=0.8005, val_loss=0.5978, longitudinal=0.3470, lateral=0.6359
# Epoch 07: train_loss=0.7377, val_loss=0.4078, longitudinal=0.3148, lateral=0.4803
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.7951)
# Epoch 08: train_loss=0.6790, val_loss=0.4194, longitudinal=0.3135, lateral=0.4686
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.7821)
# Epoch 09: train_loss=0.6136, val_loss=0.3990, longitudinal=0.3060, lateral=0.4544
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.7604)
# Epoch 10: train_loss=0.5854, val_loss=0.3475, longitudinal=0.3136, lateral=0.3839
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.6975)
# Epoch 11: train_loss=0.5394, val_loss=0.4757, longitudinal=0.2945, lateral=0.5723
# Epoch 12: train_loss=0.5321, val_loss=0.3829, longitudinal=0.3031, lateral=0.4425
# Epoch 13: train_loss=0.5036, val_loss=0.3634, longitudinal=0.3023, lateral=0.3847
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.6870)
# Epoch 14: train_loss=0.4838, val_loss=0.3210, longitudinal=0.2968, lateral=0.3430
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.6398)
# Epoch 15: train_loss=0.4578, val_loss=0.4155, longitudinal=0.2742, lateral=0.5109
# Epoch 16: train_loss=0.4446, val_loss=0.6103, longitudinal=0.2730, lateral=0.7673
# Epoch 17: train_loss=0.4312, val_loss=0.3438, longitudinal=0.2931, lateral=0.3788
# Epoch 18: train_loss=0.4348, val_loss=0.4860, longitudinal=0.2627, lateral=0.5468
# Epoch 19: train_loss=0.4188, val_loss=0.4188, longitudinal=0.3714, lateral=0.4295
# Epoch 20: train_loss=0.4533, val_loss=0.3039, longitudinal=0.2584, lateral=0.3305
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.5889)
# Epoch 21: train_loss=0.3813, val_loss=0.4059, longitudinal=0.2550, lateral=0.5258
# Epoch 22: train_loss=0.3760, val_loss=0.4169, longitudinal=0.2700, lateral=0.5096
# Epoch 23: train_loss=0.3827, val_loss=0.4266, longitudinal=0.3229, lateral=0.4829
# Epoch 24: train_loss=0.3847, val_loss=0.4869, longitudinal=0.2452, lateral=0.6345
# Epoch 25: train_loss=0.3489, val_loss=0.3537, longitudinal=0.2769, lateral=0.3789
# Epoch 26: train_loss=0.3450, val_loss=0.4271, longitudinal=0.2749, lateral=0.5247
# Epoch 27: train_loss=0.3412, val_loss=0.3890, longitudinal=0.2459, lateral=0.4609
# Epoch 28: train_loss=0.3353, val_loss=0.2887, longitudinal=0.2428, lateral=0.3456
#   -> New best model saved to /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th (L1=0.5884)
# Epoch 29: train_loss=0.3490, val_loss=0.3415, longitudinal=0.2611, lateral=0.4046
# Epoch 30: train_loss=0.3320, val_loss=0.3953, longitudinal=0.2426, lateral=0.4715
# Best model already saved at /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/homework/cnn_planner.th with L1=0.5884

# %% [markdown]
# ## Grader
#
# Run the following cell to grade your homework.
#
# Note: if you don't set up PySuperTuxKart, the grader will not run the driving tests.

# %%
# !python3 -m grader homework -vv --disable_color
# Out:
# Public grader loaded.
# [DEBUG    00:00:000] Loading assignment
# [DEBUG    00:00:000] Loading grader
# [INFO     00:00:001] MLP Planner
# [DEBUG    00:00:057] Loaded 2000 samples from 4 episodes
# [INFO     00:00:326]   - Test Output Shape                                  [ 5 / 5 ]
# [INFO     00:01:527]   - Longitudinal Error                                 [ 10 / 10 ]
# [WARNING  00:01:527] longitudinal_error: 0.154, required < 0.2
# [INFO     00:01:527]   - Longitudinal Error: Extra Credit                   [ 1 / 1 ]
# [INFO     00:01:527]   - Lateral Error                                      [ 10 / 10 ]
# [WARNING  00:01:527] lateral_error: 0.418, required < 0.6
# [INFO     00:01:527]   - Lateral Error: Extra Credit                        [ 1 / 1 ]
# [DEBUG    00:01:528] No module named 'pystk'
# [WARNING  00:01:528]   - Driving Performance                                [ 0 / 10 ]
# [WARNING  00:01:528] Skipping test (pystk not installed).
# [INFO     00:01:528]  --------------------------------------------------    [  27 /  35 ]
# [INFO     00:01:529] Transformer Planner
# [DEBUG    00:01:564] Loaded 2000 samples from 4 episodes
# [INFO     00:01:582]   - Test Output Shape                                  [ 5 / 5 ]
# [INFO     00:02:872]   - Longitudinal Error                                 [ 10 / 10 ]
# [WARNING  00:02:872] longitudinal_error: 0.148, required < 0.2
# [INFO     00:02:872]   - Longitudinal Error: Extra Credit                   [ 1 / 1 ]
# [WARNING  00:02:872]   - Lateral Error                                      [ 0 / 10 ]
# [WARNING  00:02:872] lateral_error: 0.811, required < 0.6
# [WARNING  00:02:872]   - Lateral Error: Extra Credit                        [ 0 / 1 ]
# [DEBUG    00:02:872] No module named 'pystk'
# [WARNING  00:02:873]   - Driving Performance                                [ 0 / 10 ]
# [WARNING  00:02:873] Skipping test (pystk not installed).
# [INFO     00:02:873]  --------------------------------------------------    [  16 /  35 ]
# [INFO     00:02:874] CNN Planner
# [DEBUG    00:02:908] Loaded 2000 samples from 4 episodes
# [INFO     00:03:091]   - Test Output Shape                                  [ 5 / 5 ]
# [INFO     00:05:334]   - Longitudinal Error                                 [ 10 / 10 ]
# [WARNING  00:05:334] longitudinal_error: 0.243, required < 0.3
# [INFO     00:05:334]   - Longitudinal Error: Extra Credit                   [ 1 / 1 ]
# [INFO     00:05:334]   - Lateral Error                                      [ 10 / 10 ]
# [WARNING  00:05:334] lateral_error: 0.346, required < 0.45
# [INFO     00:05:334]   - Lateral Error: Extra Credit                        [ 1 / 1 ]
# [WARNING  00:05:335]   - Driving Performance                                [ 0 / 5 ]
# [WARNING  00:05:335] Skipping test (pystk not installed).
# [INFO     00:05:335]  --------------------------------------------------    [  27 /  30 ]
# [INFO     00:05:335] Total                                                     70 / 100

# %% [markdown]
# ## PySuperTuxKart Setup (Optional)
#
# We will use your trained planner to drive around in SuperTuxKart!
# SuperTuxKart is a python wrapper around a C++ game, so it requires a few more build steps.
#
# This is optional to test locally - if your planner passes the local grader's tests for prediction accuracy, it should drive just fine and you can submit to the online grader. You only need to set up PySuperTuxKart locally if you want to see your model driving around.

# %%
# don't worry about the "... is not a symbolic link" logs
# !sudo DEBIAN_FRONTEND=noninteractive apt install -qq libnvidia-gl-550
# !pip install PySuperTuxKartData --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk
# !pip install PySuperTuxKart --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk

# %% [markdown]
# ## End to End Driving Visualization
#
# After your models are trained, you can see how they perform in game!
#
# Some of the driving might look "jittery", due to the simple logic of the controller (directly steer towards the predicted waypoints).
#
# You can always tweak the controller for fun, but note that we will use the original one for grading.

# %%
# This script will simply run your model and save the session as a video
# !python3 -m homework.supertux_utils.evaluate --model mlp_planner --track lighthouse --max-steps 100

# %%
# This cell displays the videos
from IPython.display import Video
from pathlib import Path


video_dir = Path("videos")

for video_path in sorted(video_dir.glob("*.mp4")):
    print(video_path)
    display(Video(video_path, embed=True))

# %% [markdown]
# ## Update your changes

# %%
# %ls
# !git status

# Be careful not to "git add *" since there are datasets and logs
# !git add homework/*.py
# !git config --global user.email "GITHUB_EMAIL"
# !git config --global user.name "GITHUB_USER"
# !git commit -m "update"
# !git push origin main

# %% [markdown]
# ## Submission
#
# Run the following cell to bundle your submission (modify UTID accordingly).
#
# If you notice that your bundle is too large, you can modify the `bundle.py` script and ignore large files by adding them manually to `BLACKLIST`.
#
# After the bundler and grader run, right click and download your bundled `.zip` file from the Colab UI.

# %%
# !python3 bundle.py homework as238863

# optional: run the grader with your bundled homework to double check
# !python3 -m grader UTID.zip -vv --disable_color
# Out:
# cnn_planner.th
# datasets
# supertux_utils
# models.py
# mlp_planner.th
# transformer_planner.th
# __init__.py
# metrics.py
# train_planner.py
# datasets/road_transforms.py
# datasets/road_dataset.py
# datasets/road_utils.py
# supertux_utils/video_visualization.py
# supertux_utils/evaluate.py
# Submission created: /content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/as238863.zip 1.99 MB
# Public grader loaded.
# [DEBUG    00:00:000] Loading assignment
# Traceback (most recent call last):
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/grader/__main__.py", line 13, in <module>
#     run()
#   File "/content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/grader/grader.py", line 349, in run
#     assignment = load_assignment(logger, args.assignment)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/MSDS-UT-Austin/Deep Learning/Assignment/homework4/grader/grader.py", line 245, in load_assignment
#     with zipfile.ZipFile(assignment_path) as f:
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.12/zipfile/__init__.py", line 1352, in __init__
#     self.fp = io.open(file, filemode)
#               ^^^^^^^^^^^^^^^^^^^^^^^
# FileNotFoundError: [Errno 2] No such file or directory: 'UTID.zip'

# %% [markdown]
# ## Tensorboard (Optional)

# %%
# %load_ext tensorboard
# %tensorboard --logdir logs

# %%
# !sudo DEBIAN_FRONTEND=noninteractive apt install -qq libnvidia-gl-535
# !pip install PySuperTuxKartData --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk -vv
# !pip install PySuperTuxKart --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk -vv

# %%
# !python -v
